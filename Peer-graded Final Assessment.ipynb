# %% [markdown]
# # Introduction (business problem)

# %% [markdown]
# Paris is the capital and most populous city of France, with an estimated population of 2,175,601 residents as of 2018, in an area of more than 105 square kilometres (41 square miles). Since the 17th century, Paris has been one of Europe's major centres of finance, diplomacy, commerce, fashion, science and arts.
#
# According to the Euromonitor Global Cities Destination Index, Paris is the second-busiest airline destination in the world, with 19.10 million visitors, behind Bangkok (22.78 million) but ahead of London (19.09 million). According to the Paris Convention and Visitors Bureau, 393,008 workers in Greater Paris, or 12.4% of the total workforce, are engaged in tourism-related sectors such as hotels, catering, transport and leisure.
#
# Greater Paris, comprising Paris and its three surrounding departments, received 38 million visitors in 2019, a record, measured by hotel arrivals. These included 12.2 million French visitors. Of foreign visitors, the greatest number came from the United States (2.6 million), United Kingdom (1.2 million), Germany (981 thousand) and China (711 thousand).
#
# It is interesting to explore the city-center sightseeing. It can be useful for the tourists coming to Paris.

# %% [markdown]
# # Data

# %% [markdown]
# In this Notebook I will explore Paris from two different angles: its public gardens an their distance from the city-center and the density of the popular places in the city-center. I use La Place de la Concorde as the center point of the city.
#
# I use the Foursquare API. Its data for Paris is, unfortunately, limited.

# %% [markdown]
# ## Data preparation

# %%
#importing the necessary libraries

import requests
import pandas as pd
import numpy as np
import random


# !pip install geopy
from geopy.geocoders import Nominatim

from IPython.display import Image 
from IPython.core.display import HTML 
    
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# Collecting folium==0.5.0
#   Downloading folium-0.5.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 6.9 MB/s  eta 0:00:01
# Requirement already satisfied: branca in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.25.9)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76240 sha256=2fd3585aa5ab4c120d78bff1f93d706917601d874e80b4f558bf2dd3939b8c1b
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/b2/2f/2c/109e446b990d663ea5ce9b078b5e7c1a9c45cca91f377080f8
# Successfully built folium
# Installing collected packages: folium
#   Attempting uninstall: folium
#     Found existing installation: folium 0.12.1
#     Uninstalling folium-0.12.1:
#       Successfully uninstalled folium-0.12.1
# Successfully installed folium-0.5.0
# Folium installed
# Libraries imported.

# %%
#importing the necessary keys

CLIENT_ID = '5JAXSZRX035SR2MBU3J3GHQY1EF0ZD5VVENVEY3UJ4OFO0U0'
CLIENT_SECRET = 'G2B5HMMHBEVQ5QI2JDWXYFAG1U5I4NAA11KVNQBVSFC05GZG' 
ACCESS_TOKEN = 'VA0SECL4SPWWSDVJFMIJMEWRRRTKKCMX1XDDL0KUAF4OLISQ'
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 5JAXSZRX035SR2MBU3J3GHQY1EF0ZD5VVENVEY3UJ4OFO0U0
# CLIENT_SECRET:G2B5HMMHBEVQ5QI2JDWXYFAG1U5I4NAA11KVNQBVSFC05GZG

# %%
#indicating the city-center

address = '1 Place de la Concorde, Paris, France'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 48.863856 2.3214879

# %%
#Searching for the gardens

search_query = 'Jardin'
radius = 10000
print(search_query + ' .... OK!')
# Out:
# Jardin .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=5JAXSZRX035SR2MBU3J3GHQY1EF0ZD5VVENVEY3UJ4OFO0U0&client_secret=G2B5HMMHBEVQ5QI2JDWXYFAG1U5I4NAA11KVNQBVSFC05GZG&ll=48.863856,2.3214879&oauth_token=VA0SECL4SPWWSDVJFMIJMEWRRRTKKCMX1XDDL0KUAF4OLISQ&v=20180604&query=Jardin&radius=10000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60323667078f3e56b878e71e'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 84}}],
#  'response': {'venues': [{'id': '4b30f9bbf964a5208ffd24e3',
#     'name': 'Tuileries Garden (Jardin des Tuileries)',
#     'location': {'address': 'Rue de Rivoli',
#      'crossStreet': 'Quai des Tuileries',
#      'lat': 48.863641957269515,
#      'lng': 2.326483726501465,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.863641957269515,
#        'lng': 2.326483726501465}],
#      'distance': 366,
#      'postalCode': '75001',
#      'cc': 'FR',
#      'neighborhood': 'Tuilerie',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Rue de Rivoli (Quai des Tuileries)',
#       '75001 Paris',
#       'France']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4ba8b203f964a520a6e739e3',
#     'name': 'Luxembourg Garden (Jardin du Luxembourg)',
#     'location': {'address': 'Place Edmond Rostand',
#      'lat': 48.84705290819862,
#      'lng': 2.3365044593811035,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.84705290819862,
#        'lng': 2.3365044593811035}],
#      'distance': 2169,
#      'postalCode': '75006',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Place Edmond Rostand', '75006 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4ba8b650f964a520f5e839e3',
#     'name': 'Jardin du Palais Royal',
#     'location': {'address': 'Palais Royal',
#      'lat': 48.86494061245833,
#      'lng': 2.3377275466918945,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86494061245833,
#        'lng': 2.3377275466918945}],
#      'distance': 1195,
#      'postalCode': '75001',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Palais Royal', '75001 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '50d341c7e4b03474901dccaa',
#     'name': "Le Jardin d'Hiver",
#     'location': {'address': 'Hôtel de Crillon',
#      'crossStreet': '10 place de la Concorde',
#      'lat': 48.867393,
#      'lng': 2.321239,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.867393,
#        'lng': 2.321239}],
#      'distance': 394,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'neighborhood': 'Madeleine',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Hôtel de Crillon (10 place de la Concorde)',
#       '75008 Paris',
#       'France']},
#     'categories': [{'id': '4bf58dd8d48988d1dc931735',
#       'name': 'Tea Room',
#       'pluralName': 'Tea Rooms',
#       'shortName': 'Tea Room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4e75f4df1495be517157dffe',
#     'name': 'Jardin des Ambassadeurs',
#     'location': {'address': 'Avenue des Champs-Élysées',
#      'lat': 48.867213177949374,
#      'lng': 2.317514419555664,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.867213177949374,
#        'lng': 2.317514419555664}],
#      'distance': 473,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Avenue des Champs-Élysées',
#       '75008 Paris',
#       'France']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '5b2c01c5f79faa002cc3ae5f',
#     'name': 'Jardin du Petit Palais',
#     'location': {'address': 'Petit Palais',
#      'lat': 48.86601905580683,
#      'lng': 2.3149474856781818,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86601905580683,
#        'lng': 2.3149474856781818}],
#      'distance': 536,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Petit Palais', '75008 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4baf722cf964a52065003ce3',
#     'name': 'Café Le Jardin du Petit Palais',
#     'location': {'address': '1 avenue Dutuit',
#      'lat': 48.8660350672302,
#      'lng': 2.314743723943765,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.8660350672302,
#        'lng': 2.314743723943765}],
#      'distance': 550,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'neighborhood': 'Champs-Élysées',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['1 avenue Dutuit', '75008 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '500c2fc4e4b0fec2ce0cf82d',
#     'name': 'Jardin Anne Sauvage',
#     'location': {'address': 'Cours la Reine',
#      'crossStreet': 'Jardin de la Nouvelle France',
#      'lat': 48.865200316753324,
#      'lng': 2.3107734075456285,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.865200316753324,
#        'lng': 2.3107734075456285}],
#      'distance': 798,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Cours la Reine (Jardin de la Nouvelle France)',
#       '75008 Paris',
#       'France']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4fc8ecc0e4b083bc78fa8bfd',
#     'name': 'Jardin du Théâtre du Rond Point',
#     'location': {'address': 'Avenue des Champs-Élysées',
#      'lat': 48.868090044581216,
#      'lng': 2.3115548233206145,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.868090044581216,
#        'lng': 2.3115548233206145}],
#      'distance': 866,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Avenue des Champs-Élysées',
#       '75008 Paris',
#       'France']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4dc790c01fc72e86376fc69c',
#     'name': 'Jardin du Musée Rodin',
#     'location': {'address': '79 rue de Varenne',
#      'crossStreet': 'Musée Rodin',
#      'lat': 48.85583847334092,
#      'lng': 2.3158099297222425,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85583847334092,
#        'lng': 2.3158099297222425}],
#      'distance': 984,
#      'postalCode': '75014',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['79 rue de Varenne (Musée Rodin)',
#       '75014 Paris',
#       'France']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4ba8b62df964a520eee839e3',
#     'name': 'Jardin de Sciences Po',
#     'location': {'address': '27 rue Saint-Guillaume',
#      'crossStreet': 'Sciences Po Paris',
#      'lat': 48.85391092809383,
#      'lng': 2.329098833694411,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85391092809383,
#        'lng': 2.329098833694411}],
#      'distance': 1239,
#      'postalCode': '75007',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['27 rue Saint-Guillaume (Sciences Po Paris)',
#       '75007 Paris',
#       'France']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '50d5edffe4b0b7ab7c88fa48',
#     'name': 'Le Jardin Saint-Honoré',
#     'location': {'address': '56 rue du Colisée',
#      'lat': 48.87204890080593,
#      'lng': 2.3121325671672817,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.87204890080593,
#        'lng': 2.3121325671672817}],
#      'distance': 1140,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['56 rue du Colisée', '75008 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d11b951735',
#       'name': 'Flower Shop',
#       'pluralName': 'Flower Shops',
#       'shortName': 'Flower Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/flowershop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4da2e93abf22a143e08bbbf8',
#     'name': "Sciences Po - Le Jardin du 13 de la rue de l'Université",
#     'location': {'address': "13 rue de l'Université",
#      'lat': 48.857087016476704,
#      'lng': 2.329825377481412,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.857087016476704,
#        'lng': 2.329825377481412}],
#      'distance': 969,
#      'postalCode': '75007',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ["13 rue de l'Université", '75007 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4b91210ff964a52066a533e3',
#     'name': 'Jardin Nelson Mandela',
#     'location': {'address': '1 rue Pierre-Lescot',
#      'crossStreet': 'Les Halles',
#      'lat': 48.86268835131577,
#      'lng': 2.3444847910601943,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86268835131577,
#        'lng': 2.3444847910601943}],
#      'distance': 1689,
#      'postalCode': '75001',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['1 rue Pierre-Lescot (Les Halles)',
#       '75001 Paris',
#       'France']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4c8125b3d4e2370499d85a88',
#     'name': "Jardin des Invalides – Jardin de l'Intendant",
#     'location': {'address': 'Place Vauban',
#      'lat': 48.85399501040262,
#      'lng': 2.311720243624729,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85399501040262,
#        'lng': 2.311720243624729}],
#      'distance': 1310,
#      'postalCode': '75007',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Place Vauban', '75007 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '50cf0750e4b0b0b98dbbdd64',
#     'name': 'Le Jardin des Lilas',
#     'location': {'address': '49 rue de Laborde',
#      'lat': 48.87543288726831,
#      'lng': 2.3175090551376343,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.87543288726831,
#        'lng': 2.3175090551376343}],
#      'distance': 1321,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['49 rue de Laborde', '75008 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4e02ea05cc3f56036957fc32',
#     'name': 'Jardin de la rue Visconti',
#     'location': {'address': 'Entre le 8 et 12 de la rue Visconti',
#      'lat': 48.85572225448922,
#      'lng': 2.3354852199554443,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.85572225448922,
#        'lng': 2.3354852199554443}],
#      'distance': 1367,
#      'postalCode': '75006',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Entre le 8 et 12 de la rue Visconti',
#       '75006 Paris',
#       'France']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '503792f2e4b0be420ebc2f6a',
#     'name': 'Jardin du musée du Quai Branly – Jacques Chirac',
#     'location': {'address': '37 quai Branly',
#      'lat': 48.86115747952929,
#      'lng': 2.297537326812744,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86115747952929,
#        'lng': 2.297537326812744}],
#      'distance': 1779,
#      'postalCode': '75007',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['37 quai Branly', '75007 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4e9dd49eb6348df6f7490f21',
#     'name': 'Le Jardin de Rome',
#     'location': {'address': '52 rue de Rome',
#      'lat': 48.87922672645601,
#      'lng': 2.3220184506097565,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.87922672645601,
#        'lng': 2.3220184506097565}],
#      'distance': 1711,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['52 rue de Rome', '75008 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '594d5d7228374e6b9ac0dbe3',
#     'name': "Jardin de l'Hôtel de Béhague",
#     'location': {'address': 'Hôtel de Béhague',
#      'crossStreet': '123 rue Saint-Dominique',
#      'lat': 48.858036,
#      'lng': 2.303323,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.858036,
#        'lng': 2.303323}],
#      'distance': 1479,
#      'postalCode': '75007',
#      'cc': 'FR',
#      'neighborhood': 'Gros-Caillou',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Hôtel de Béhague (123 rue Saint-Dominique)',
#       '75007 Paris',
#       'France']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4e3ae95cfa766e76ed483c94',
#     'name': 'La Cour Jardin',
#     'location': {'address': '25 avenue Montaigne',
#      'crossStreet': '25 avenue Montaigne',
#      'lat': 48.866117111024316,
#      'lng': 2.3041294333397673,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.866117111024316,
#        'lng': 2.3041294333397673}],
#      'distance': 1295,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['25 avenue Montaigne (25 avenue Montaigne)',
#       '75008 Paris',
#       'France']},
#     'categories': [{'id': '4bf58dd8d48988d10c941735',
#       'name': 'French Restaurant',
#       'pluralName': 'French Restaurants',
#       'shortName': 'French',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '51d096e9498e99bf5aae4b98',
#     'name': 'Archipel des Berges de Seine | Jardin flottant Niki de Saint Phalle',
#     'location': {'address': 'Port du Gros Caillou',
#      'lat': 48.86311271997676,
#      'lng': 2.304603688819762,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86311271997676,
#        'lng': 2.304603688819762}],
#      'distance': 1239,
#      'postalCode': '75007',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Port du Gros Caillou', '75007 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4adcda09f964a520fe3321e3',
#     'name': 'Gardens of the Champs-Élysées (Jardins des Champs-Élysées)',
#     'location': {'address': 'Avenue des Champs-Élysées',
#      'lat': 48.86785025032083,
#      'lng': 2.314540838373373,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86785025032083,
#        'lng': 2.314540838373373}],
#      'distance': 675,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Avenue des Champs-Élysées',
#       '75008 Paris',
#       'France']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4bbb21da935e9521aac82890',
#     'name': 'Jardin Anne Frank',
#     'location': {'address': 'Impasse Berthaud',
#      'lat': 48.86169546412832,
#      'lng': 2.3549842888314743,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86169546412832,
#        'lng': 2.3549842888314743}],
#      'distance': 2464,
#      'postalCode': '75003',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Impasse Berthaud', '75003 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '53382880498ef9cde48fcd0d',
#     'name': 'Ruches du Jardin du Luxembourg',
#     'location': {'address': 'Jardin du Luxembourg',
#      'lat': 48.8452202103479,
#      'lng': 2.333176858523463,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.8452202103479,
#        'lng': 2.333176858523463}],
#      'distance': 2244,
#      'postalCode': '75006',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Jardin du Luxembourg', '75006 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d162941735',
#       'name': 'Other Great Outdoors',
#       'pluralName': 'Other Great Outdoors',
#       'shortName': 'Other Outdoors',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4b7d9d99f964a52003ca2fe3',
#     'name': 'Le Jardin des Créateurs',
#     'location': {'address': '20 rue Montmartre',
#      'lat': 48.864077,
#      'lng': 2.345658,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.864077,
#        'lng': 2.345658}],
#      'distance': 1770,
#      'postalCode': '75001',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['20 rue Montmartre', '75001 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d104951735',
#       'name': 'Boutique',
#       'pluralName': 'Boutiques',
#       'shortName': 'Boutique',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4fc24fcfe4b07ac9fcf3f01e',
#     'name': "Jardin de l'Hôtel Salomon de Rothshild",
#     'location': {'address': '11, rue de Berryer',
#      'lat': 48.874919250630924,
#      'lng': 2.302578542504987,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.874919250630924,
#        'lng': 2.302578542504987}],
#      'distance': 1853,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['11, rue de Berryer', '75008 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4bfa691c8d30d13ac07f0318',
#     'name': "Jardin de l'Hôtel Salé - Léonor Fini",
#     'location': {'address': '109 rue Vieille du Temple',
#      'lat': 48.86012,
#      'lng': 2.361595,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86012,
#        'lng': 2.361595}],
#      'distance': 2966,
#      'postalCode': '75003',
#      'cc': 'FR',
#      'neighborhood': 'Marais, Paris',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['109 rue Vieille du Temple',
#       '75003 Paris',
#       'France']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4bd0684b046076b0bbdb6f71',
#     'name': 'Carrousel Garden (Jardin du Carrousel)',
#     'location': {'address': 'Jardins du Carrousel',
#      'lat': 48.86205640499456,
#      'lng': 2.3324446522511044,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.86205640499456,
#        'lng': 2.3324446522511044}],
#      'distance': 827,
#      'postalCode': '75001',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['Jardins du Carrousel', '75001 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d15a941735',
#       'name': 'Garden',
#       'pluralName': 'Gardens',
#       'shortName': 'Garden',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False},
#    {'id': '4adcda13f964a520d73621e3',
#     'name': 'Jardin (Le)',
#     'location': {'address': '37 Ave. Hoche',
#      'lat': 48.876353644885945,
#      'lng': 2.304422872989122,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 48.876353644885945,
#        'lng': 2.304422872989122}],
#      'distance': 1869,
#      'postalCode': '75008',
#      'cc': 'FR',
#      'city': 'Paris',
#      'state': 'Île-de-France',
#      'country': 'France',
#      'formattedAddress': ['37 Ave. Hoche', '75008 Paris', 'France']},
#     'categories': [{'id': '4bf58dd8d48988d10c941735',
#       'name': 'French Restaurant',
#       'pluralName': 'French Restaurants',
#       'shortName': 'French',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1613903463',
#     'hasPerk': False}]}}

# %%
#creating a table

venues = results['response']['venues']

dataframe = pd.json_normalize(venues)
dataframe.head()
# Out:
#                          id                                      name  \
# 0  4b30f9bbf964a5208ffd24e3   Tuileries Garden (Jardin des Tuileries)
# 1  4ba8b203f964a520a6e739e3  Luxembourg Garden (Jardin du Luxembourg)
# 2  4ba8b650f964a520f5e839e3                    Jardin du Palais Royal
# 3  50d341c7e4b03474901dccaa                         Le Jardin d'Hiver
# 4  4e75f4df1495be517157dffe                   Jardin des Ambassadeurs
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d15a941735', 'name': 'G...  v-1613903463    False
# 1  [{'id': '4bf58dd8d48988d15a941735', 'name': 'G...  v-1613903463    False
# 2  [{'id': '4bf58dd8d48988d15a941735', 'name': 'G...  v-1613903463    False
# 3  [{'id': '4bf58dd8d48988d1dc931735', 'name': 'T...  v-1613903463    False
# 4  [{'id': '4bf58dd8d48988d15a941735', 'name': 'G...  v-1613903463    False
#
#             location.address     location.crossStreet  location.lat  \
# 0              Rue de Rivoli       Quai des Tuileries     48.863642
# 1       Place Edmond Rostand                      NaN     48.847053
# 2               Palais Royal                      NaN     48.864941
# 3           Hôtel de Crillon  10 place de la Concorde     48.867393
# 4  Avenue des Champs-Élysées                      NaN     48.867213
#
#    location.lng                            location.labeledLatLngs  \
# 0      2.326484  [{'label': 'display', 'lat': 48.86364195726951...
# 1      2.336504  [{'label': 'display', 'lat': 48.84705290819862...
# 2      2.337728  [{'label': 'display', 'lat': 48.86494061245833...
# 3      2.321239  [{'label': 'display', 'lat': 48.867393, 'lng':...
# 4      2.317514  [{'label': 'display', 'lat': 48.86721317794937...
#
#    location.distance location.postalCode location.cc location.neighborhood  \
# 0                366               75001          FR              Tuilerie
# 1               2169               75006          FR                   NaN
# 2               1195               75001          FR                   NaN
# 3                394               75008          FR             Madeleine
# 4                473               75008          FR                   NaN
#
#   location.city location.state location.country  \
# 0         Paris  Île-de-France           France
# 1         Paris  Île-de-France           France
# 2         Paris  Île-de-France           France
# 3         Paris  Île-de-France           France
# 4         Paris  Île-de-France           France
#
#                            location.formattedAddress
# 0  [Rue de Rivoli (Quai des Tuileries), 75001 Par...
# 1        [Place Edmond Rostand, 75006 Paris, France]
# 2                [Palais Royal, 75001 Paris, France]
# 3  [Hôtel de Crillon (10 place de la Concorde), 7...
# 4   [Avenue des Champs-Élysées, 75008 Paris, France]

# %%
#cleaning the table

filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head(100)
# Out:
#                                                  name            categories  \
# 0             Tuileries Garden (Jardin des Tuileries)                Garden
# 1            Luxembourg Garden (Jardin du Luxembourg)                Garden
# 2                              Jardin du Palais Royal                Garden
# 3                                   Le Jardin d'Hiver              Tea Room
# 4                             Jardin des Ambassadeurs                Garden
# 5                              Jardin du Petit Palais                Garden
# 6                      Café Le Jardin du Petit Palais                  Café
# 7                                 Jardin Anne Sauvage                  Park
# 8                     Jardin du Théâtre du Rond Point                Garden
# 9                               Jardin du Musée Rodin                Garden
# 10                              Jardin de Sciences Po                Garden
# 11                             Le Jardin Saint-Honoré           Flower Shop
# 12  Sciences Po - Le Jardin du 13 de la rue de l'U...                  Park
# 13                              Jardin Nelson Mandela                  Park
# 14       Jardin des Invalides – Jardin de l'Intendant                Garden
# 15                                Le Jardin des Lilas            Restaurant
# 16                          Jardin de la rue Visconti                Garden
# 17    Jardin du musée du Quai Branly – Jacques Chirac                Garden
# 18                                  Le Jardin de Rome                  Café
# 19                       Jardin de l'Hôtel de Béhague                Garden
# 20                                     La Cour Jardin     French Restaurant
# 21  Archipel des Berges de Seine | Jardin flottant...                Garden
# 22  Gardens of the Champs-Élysées (Jardins des Cha...                Garden
# 23                                  Jardin Anne Frank                Garden
# 24                     Ruches du Jardin du Luxembourg  Other Great Outdoors
# 25                            Le Jardin des Créateurs              Boutique
# 26             Jardin de l'Hôtel Salomon de Rothshild                  Park
# 27               Jardin de l'Hôtel Salé - Léonor Fini                  Park
# 28             Carrousel Garden (Jardin du Carrousel)                Garden
# 29                                        Jardin (Le)     French Restaurant
#
#                                 address                   crossStreet  \
# 0                         Rue de Rivoli            Quai des Tuileries
# 1                  Place Edmond Rostand                           NaN
# 2                          Palais Royal                           NaN
# 3                      Hôtel de Crillon       10 place de la Concorde
# 4             Avenue des Champs-Élysées                           NaN
# 5                          Petit Palais                           NaN
# 6                       1 avenue Dutuit                           NaN
# 7                        Cours la Reine  Jardin de la Nouvelle France
# 8             Avenue des Champs-Élysées                           NaN
# 9                     79 rue de Varenne                   Musée Rodin
# 10               27 rue Saint-Guillaume             Sciences Po Paris
# 11                    56 rue du Colisée                           NaN
# 12               13 rue de l'Université                           NaN
# 13                  1 rue Pierre-Lescot                    Les Halles
# 14                         Place Vauban                           NaN
# 15                    49 rue de Laborde                           NaN
# 16  Entre le 8 et 12 de la rue Visconti                           NaN
# 17                       37 quai Branly                           NaN
# 18                       52 rue de Rome                           NaN
# 19                     Hôtel de Béhague       123 rue Saint-Dominique
# 20                  25 avenue Montaigne           25 avenue Montaigne
# 21                 Port du Gros Caillou                           NaN
# 22            Avenue des Champs-Élysées                           NaN
# 23                     Impasse Berthaud                           NaN
# 24                 Jardin du Luxembourg                           NaN
# 25                    20 rue Montmartre                           NaN
# 26                   11, rue de Berryer                           NaN
# 27            109 rue Vieille du Temple                           NaN
# 28                 Jardins du Carrousel                           NaN
# 29                        37 Ave. Hoche                           NaN
#
#           lat       lng                                     labeledLatLngs  \
# 0   48.863642  2.326484  [{'label': 'display', 'lat': 48.86364195726951...
# 1   48.847053  2.336504  [{'label': 'display', 'lat': 48.84705290819862...
# 2   48.864941  2.337728  [{'label': 'display', 'lat': 48.86494061245833...
# 3   48.867393  2.321239  [{'label': 'display', 'lat': 48.867393, 'lng':...
# 4   48.867213  2.317514  [{'label': 'display', 'lat': 48.86721317794937...
# 5   48.866019  2.314947  [{'label': 'display', 'lat': 48.86601905580683...
# 6   48.866035  2.314744  [{'label': 'display', 'lat': 48.8660350672302,...
# 7   48.865200  2.310773  [{'label': 'display', 'lat': 48.86520031675332...
# 8   48.868090  2.311555  [{'label': 'display', 'lat': 48.86809004458121...
# 9   48.855838  2.315810  [{'label': 'display', 'lat': 48.85583847334092...
# 10  48.853911  2.329099  [{'label': 'display', 'lat': 48.85391092809383...
# 11  48.872049  2.312133  [{'label': 'display', 'lat': 48.87204890080593...
# 12  48.857087  2.329825  [{'label': 'display', 'lat': 48.85708701647670...
# 13  48.862688  2.344485  [{'label': 'display', 'lat': 48.86268835131577...
# 14  48.853995  2.311720  [{'label': 'display', 'lat': 48.85399501040262...
# 15  48.875433  2.317509  [{'label': 'display', 'lat': 48.87543288726831...
# 16  48.855722  2.335485  [{'label': 'display', 'lat': 48.85572225448922...
# 17  48.861157  2.297537  [{'label': 'display', 'lat': 48.86115747952929...
# 18  48.879227  2.322018  [{'label': 'display', 'lat': 48.87922672645601...
# 19  48.858036  2.303323  [{'label': 'display', 'lat': 48.858036, 'lng':...
# 20  48.866117  2.304129  [{'label': 'display', 'lat': 48.86611711102431...
# 21  48.863113  2.304604  [{'label': 'display', 'lat': 48.86311271997676...
# 22  48.867850  2.314541  [{'label': 'display', 'lat': 48.86785025032083...
# 23  48.861695  2.354984  [{'label': 'display', 'lat': 48.86169546412832...
# 24  48.845220  2.333177  [{'label': 'display', 'lat': 48.8452202103479,...
# 25  48.864077  2.345658  [{'label': 'display', 'lat': 48.864077, 'lng':...
# 26  48.874919  2.302579  [{'label': 'display', 'lat': 48.87491925063092...
# 27  48.860120  2.361595  [{'label': 'display', 'lat': 48.86012, 'lng': ...
# 28  48.862056  2.332445  [{'label': 'display', 'lat': 48.86205640499456...
# 29  48.876354  2.304423  [{'label': 'display', 'lat': 48.87635364488594...
#
#     distance postalCode  cc    neighborhood   city          state country  \
# 0        366      75001  FR        Tuilerie  Paris  Île-de-France  France
# 1       2169      75006  FR             NaN  Paris  Île-de-France  France
# 2       1195      75001  FR             NaN  Paris  Île-de-France  France
# 3        394      75008  FR       Madeleine  Paris  Île-de-France  France
# 4        473      75008  FR             NaN  Paris  Île-de-France  France
# 5        536      75008  FR             NaN  Paris  Île-de-France  France
# 6        550      75008  FR  Champs-Élysées  Paris  Île-de-France  France
# 7        798      75008  FR             NaN  Paris  Île-de-France  France
# 8        866      75008  FR             NaN  Paris  Île-de-France  France
# 9        984      75014  FR             NaN  Paris  Île-de-France  France
# 10      1239      75007  FR             NaN  Paris  Île-de-France  France
# 11      1140      75008  FR             NaN  Paris  Île-de-France  France
# 12       969      75007  FR             NaN  Paris  Île-de-France  France
# 13      1689      75001  FR             NaN  Paris  Île-de-France  France
# 14      1310      75007  FR             NaN  Paris  Île-de-France  France
# 15      1321      75008  FR             NaN  Paris  Île-de-France  France
# 16      1367      75006  FR             NaN  Paris  Île-de-France  France
# 17      1779      75007  FR             NaN  Paris  Île-de-France  France
# 18      1711      75008  FR             NaN  Paris  Île-de-France  France
# 19      1479      75007  FR    Gros-Caillou  Paris  Île-de-France  France
# 20      1295      75008  FR             NaN  Paris  Île-de-France  France
# 21      1239      75007  FR             NaN  Paris  Île-de-France  France
# 22       675      75008  FR             NaN  Paris  Île-de-France  France
# 23      2464      75003  FR             NaN  Paris  Île-de-France  France
# 24      2244      75006  FR             NaN  Paris  Île-de-France  France
# 25      1770      75001  FR             NaN  Paris  Île-de-France  France
# 26      1853      75008  FR             NaN  Paris  Île-de-France  France
# 27      2966      75003  FR   Marais, Paris  Paris  Île-de-France  France
# 28       827      75001  FR             NaN  Paris  Île-de-France  France
# 29      1869      75008  FR             NaN  Paris  Île-de-France  France
#
#                                      formattedAddress  \
# 0   [Rue de Rivoli (Quai des Tuileries), 75001 Par...
# 1         [Place Edmond Rostand, 75006 Paris, France]
# 2                 [Palais Royal, 75001 Paris, France]
# 3   [Hôtel de Crillon (10 place de la Concorde), 7...
# 4    [Avenue des Champs-Élysées, 75008 Paris, France]
# 5                 [Petit Palais, 75008 Paris, France]
# 6              [1 avenue Dutuit, 75008 Paris, France]
# 7   [Cours la Reine (Jardin de la Nouvelle France)...
# 8    [Avenue des Champs-Élysées, 75008 Paris, France]
# 9   [79 rue de Varenne (Musée Rodin), 75014 Paris,...
# 10  [27 rue Saint-Guillaume (Sciences Po Paris), 7...
# 11           [56 rue du Colisée, 75008 Paris, France]
# 12      [13 rue de l'Université, 75007 Paris, France]
# 13  [1 rue Pierre-Lescot (Les Halles), 75001 Paris...
# 14                [Place Vauban, 75007 Paris, France]
# 15           [49 rue de Laborde, 75008 Paris, France]
# 16  [Entre le 8 et 12 de la rue Visconti, 75006 Pa...
# 17              [37 quai Branly, 75007 Paris, France]
# 18              [52 rue de Rome, 75008 Paris, France]
# 19  [Hôtel de Béhague (123 rue Saint-Dominique), 7...
# 20  [25 avenue Montaigne (25 avenue Montaigne), 75...
# 21        [Port du Gros Caillou, 75007 Paris, France]
# 22   [Avenue des Champs-Élysées, 75008 Paris, France]
# 23            [Impasse Berthaud, 75003 Paris, France]
# 24        [Jardin du Luxembourg, 75006 Paris, France]
# 25           [20 rue Montmartre, 75001 Paris, France]
# 26          [11, rue de Berryer, 75008 Paris, France]
# 27   [109 rue Vieille du Temple, 75003 Paris, France]
# 28        [Jardins du Carrousel, 75001 Paris, France]
# 29               [37 Ave. Hoche, 75008 Paris, France]
#
#                           id
# 0   4b30f9bbf964a5208ffd24e3
# 1   4ba8b203f964a520a6e739e3
# 2   4ba8b650f964a520f5e839e3
# 3   50d341c7e4b03474901dccaa
# 4   4e75f4df1495be517157dffe
# 5   5b2c01c5f79faa002cc3ae5f
# 6   4baf722cf964a52065003ce3
# 7   500c2fc4e4b0fec2ce0cf82d
# 8   4fc8ecc0e4b083bc78fa8bfd
# 9   4dc790c01fc72e86376fc69c
# 10  4ba8b62df964a520eee839e3
# 11  50d5edffe4b0b7ab7c88fa48
# 12  4da2e93abf22a143e08bbbf8
# 13  4b91210ff964a52066a533e3
# 14  4c8125b3d4e2370499d85a88
# 15  50cf0750e4b0b0b98dbbdd64
# 16  4e02ea05cc3f56036957fc32
# 17  503792f2e4b0be420ebc2f6a
# 18  4e9dd49eb6348df6f7490f21
# 19  594d5d7228374e6b9ac0dbe3
# 20  4e3ae95cfa766e76ed483c94
# 21  51d096e9498e99bf5aae4b98
# 22  4adcda09f964a520fe3321e3
# 23  4bbb21da935e9521aac82890
# 24  53382880498ef9cde48fcd0d
# 25  4b7d9d99f964a52003ca2fe3
# 26  4fc24fcfe4b07ac9fcf3f01e
# 27  4bfa691c8d30d13ac07f0318
# 28  4bd0684b046076b0bbdb6f71
# 29  4adcda13f964a520d73621e3

# %%
dataframe_filtered.name
# Out:
# 0               Japanese bistro
# 1             Japanese barbecue
# 2        Japanese Knife Company
# 3    MIYAKADORI, Japanese store
# 4                       Okayama
# 5                       Ao Yama
# 6                Sushi Fukunoya
# Name: name, dtype: object

# %% [markdown]
# ## Data Visualisation

# %%
#creating the map

venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3922d6065a5a4f06af103633344fc86a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3922d6065a5a4f06af103633344fc86a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3922d6065a5a4f06af103633344fc86a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3922d6065a5a4f06af103633344fc86a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B48.863856%2C%202.3214879%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Data preparation

# %%
#searching for all places of attraction arrounf the city-center

latitude = 48.863856
longitude = 2.3214879

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=5JAXSZRX035SR2MBU3J3GHQY1EF0ZD5VVENVEY3UJ4OFO0U0&client_secret=G2B5HMMHBEVQ5QI2JDWXYFAG1U5I4NAA11KVNQBVSFC05GZG&ll=48.863856,2.3214879&v=20180604&radius=10000&limit=30'

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} interesting places around la Place de la Concorde.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 interesting places around la Place de la Concorde.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4adcda09f964a520f73321e3',
#   'name': 'Place de la Concorde',
#   'location': {'address': 'Place de la Concorde',
#    'lat': 48.8655899274154,
#    'lng': 2.321215867996216,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 48.8655899274154,
#      'lng': 2.321215867996216}],
#    'distance': 194,
#    'postalCode': '75008',
#    'cc': 'FR',
#    'city': 'Paris',
#    'state': 'Île-de-France',
#    'country': 'France',
#    'formattedAddress': ['Place de la Concorde', '75008 Paris', 'France']},
#   'categories': [{'id': '4bf58dd8d48988d164941735',
#     'name': 'Plaza',
#     'pluralName': 'Plazas',
#     'shortName': 'Plaza',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-4adcda09f964a520f73321e3-0'}

# %%
#creating the table

dataframe = json_normalize(items)

filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                          name     categories                         address  \
# 0        Place de la Concorde          Plaza            Place de la Concorde
# 1        Jardin des Tuileries         Garden                   Rue de Rivoli
# 2            Hôtel de Crillon          Hotel         10 place de la Concorde
# 3               Musée d'Orsay     Art Museum    1 rue de la Légion d'Honneur
# 4         Librairie Galignani      Bookstore               224 rue de Rivoli
# 5                Grand Palais  Historic Site  3 avenue du Général Eisenhower
# 6                  Hôtel Ritz          Hotel                15 place Vendôme
# 7  Librairie du Musée d'Orsay      Bookstore    1 rue de la Légion d'Honneur
# 8         La Maison du Whisky   Liquor Store                  20 rue d'Anjou
# 9                      CHANEL       Boutique                   31 rue Cambon
#
#          lat       lng                                     labeledLatLngs  \
# 0  48.865590  2.321216  [{'label': 'display', 'lat': 48.8655899274154,...
# 1  48.863642  2.326484  [{'label': 'display', 'lat': 48.86364195726951...
# 2  48.867330  2.321141  [{'label': 'display', 'lat': 48.86732962650694...
# 3  48.859993  2.326387  [{'label': 'display', 'lat': 48.85999283813253...
# 4  48.864989  2.328570  [{'label': 'display', 'lat': 48.864989, 'lng':...
# 5  48.866112  2.312622  [{'label': 'display', 'lat': 48.86611219637595...
# 6  48.868145  2.328962  [{'label': 'display', 'lat': 48.86814475882231...
# 7  48.860031  2.326102  [{'label': 'display', 'lat': 48.86003108965947...
# 8  48.870775  2.321532  [{'label': 'display', 'lat': 48.87077532253740...
# 9  48.868189  2.326634  [{'label': 'display', 'lat': 48.86818882792764...
#
#    distance postalCode  cc   city          state country  \
# 0       194      75008  FR  Paris  Île-de-France  France
# 1       366      75001  FR  Paris  Île-de-France  France
# 2       387      75008  FR  Paris  Île-de-France  France
# 3       560      75007  FR  Paris  Île-de-France  France
# 4       533      75001  FR  Paris  Île-de-France  France
# 5       696      75008  FR  Paris  Île-de-France  France
# 6       726      75001  FR  Paris  Île-de-France  France
# 7       543      75007  FR  Paris  Île-de-France  France
# 8       770      75008  FR  Paris  Île-de-France  France
# 9       612      75001  FR  Paris  Île-de-France  France
#
#                                     formattedAddress  \
# 0        [Place de la Concorde, 75008 Paris, France]
# 1  [Rue de Rivoli (Quai des Tuileries), 75001 Par...
# 2     [10 place de la Concorde, 75008 Paris, France]
# 3  [1 rue de la Légion d'Honneur (Quai Anatole Fr...
# 4           [224 rue de Rivoli, 75001 Paris, France]
# 5  [3 avenue du Général Eisenhower (Avenue Winsto...
# 6            [15 place Vendôme, 75001 Paris, France]
# 7  [1 rue de la Légion d'Honneur, 75007 Paris, Fr...
# 8              [20 rue d'Anjou, 75008 Paris, France]
# 9  [31 rue Cambon (Rue Des Capucines), 75001 Pari...
#
#                 crossStreet neighborhood                        id
# 0                       NaN          NaN  4adcda09f964a520f73321e3
# 1        Quai des Tuileries     Tuilerie  4b30f9bbf964a5208ffd24e3
# 2                       NaN          NaN  539788f1498e4e052ed81c7b
# 3       Quai Anatole France          NaN  4adcda10f964a5208b3521e3
# 4                       NaN          NaN  4b487de3f964a5202d4e26e3
# 5  Avenue Winston Churchill          NaN  4c25f508a852c9281ab1e56c
# 6                       NaN          NaN  53b65301498e8cb57224f80c
# 7                       NaN          NaN  4eee19d802d514a36abd0d87
# 8                       NaN          NaN  4b736282f964a520d6ab2de3
# 9         Rue Des Capucines          NaN  4adcda1df964a5202a3921e3

# %% [markdown]
# ## Data visualisation

# %%
#creating the map

venues_map = folium.Map(location=[latitude, longitude], zoom_start=15)


folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f22f21c831a642ddbb3526eff31a7d0c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f22f21c831a642ddbb3526eff31a7d0c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f22f21c831a642ddbb3526eff31a7d0c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f22f21c831a642ddbb3526eff31a7d0c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B48.863856%2C%202.3214879%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ## Venue exploration

# %%
#looking for the trending venues
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '6032376e2dbbf54b00139df6'},
#  'response': {'venues': []}}

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

   columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %% [markdown]
# ## Conclusion
